# %%
from tqdm import tqdm
from collections import Counter
import seaborn as sns
from matplotlib import pyplot as plt

import numpy as np

# %%
allowed = []
with open("./wordle-allowed-guesses.txt", "r") as f:
    allowed = f.read().split('\n')	

answers = []
with open("./wordle-answers-alphabetical.txt", "r") as f:
    answers = f.read().split('\n')

# %%
allowed[50:60]
# Out:
# ['accas',
#  'accoy',
#  'acerb',
#  'acers',
#  'aceta',
#  'achar',
#  'ached',
#  'aches',
#  'achoo',
#  'acids']

# %%
def score_word(word, guess, entropy=True):
    score = ""
    words_left = set(answers.copy())
    for i, (l1, l2) in enumerate(zip(word, guess)):
        if l1 == l2:
            score += "X"
            words_left = [x for x in words_left if x[i] == l1]
        elif l2 in word:
            score += "O"
            words_left = [x for x in words_left if l1 in x]
        else:
            score += "-"
            words_left = [x for x in words_left if l1 not in x]
    return score, words_left

# %%
print(score_word("macho", "manys"))
# Out:
# ('XX---', 20)

# %%
# {k: v for k, v in sorted(x.items(), key=lambda item: item[1])}

# %%
hist = {}
scores = {}
word_paring_dict = {}
for word in tqdm(allowed):
    hist[word] = {}
    word_paring_dict[word] = {}
    scores[word] = 0.0
    for guess in answers:
        card, words_left = score_word(word, guess)
        word_paring_dict[word][guess] = words_left
        hist[word][guess] = card
        scores[word] += len(words_left)
    scores[word] /= len(answers)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10657/10657 [1:20:47<00:00,  2.20it/s]

# %%
s = {k:v for k, v in sorted(Counter(hist['aahed'].values()).items(), key=lambda i: i[1], reverse=True)}

# %%
plt.figure(figsize = (15,8))
ax = sns.barplot(x=[x for x in s.keys()], y=[y / len(answers) for y in s.values()])
ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)
plt.show()

# %%
def check_cand(guess, template, candidate):
    """ True if guess and hit/miss template is compatible 
        for a given possible answer candidate """
    for l1, l2, t in zip(guess, candidate, template):
        if l1 == l2 and t != 'X':
            # print((l1, l2), t, (guess, candidate), template, "   l1 == l2 and t != 'X':")
            return False
        if l1 != l2 and t == 'X':
            # print((l1, l2), t, (guess, candidate),template,"   l1 != l2 and t == 'X':")
            return False
        if l1 not in candidate and t == 'O':
            # print((l1, l2), t, (guess, candidate),template,"   l1 not in candidate and t == 'O':")
            return False
        if l1 in candidate and t == '-':
            # print((l1, l2), t, (guess, candidate),template,"   l1 in candidate and t == '-':")
            return False
    return True

def narrow_down(guess, template, words_left=answers.copy()):
    """ Accepts a wordle guess, and the number of words left;
        defaults to all possible words left (for 1st turn) 
        and returns list of remaining possible words """
    return [cand for cand in words_left if check_cand(guess, template, cand)]

# %%
narrow
# Out:
# ['decor',
#  'decry',
#  'mercy',
#  'perch',
#  'recur',
#  'recut',
#  'relic',
#  'retch',
#  'screw',
#  'ulcer']

# %%
turn1 = narrow_down('crane', 'OO--O')
turn2 = narrow_down('perch', '-OOO-', turn1)
turn2
# Out:
# ('c', 'a') O ('crane', 'aback')
# ('r', 'b') O ('crane', 'aback')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'abase')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'abate')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'abbey')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'abbot')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'abhor')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'abide')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'abled')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'abode')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'abort')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'about')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'above')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'abuse')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'abyss')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'acorn')
# ('r', 'c') O ('crane', 'acorn')
# ('a', 'o') - ('crane', 'acorn')
#    l1 in candidate and t == '-':
# ('c', 'a') O ('crane', 'acrid')
# ('r', 'c') O ('crane', 'acrid')
# ('a', 'r') - ('crane', 'acrid')
#    l1 in candidate and t == '-':
# ('c', 'a') O ('crane', 'actor')
# ('r', 'c') O ('crane', 'actor')
# ('a', 't') - ('crane', 'actor')
#    l1 in candidate and t == '-':
# ('c', 'a') O ('crane', 'acute')
# ('r', 'c') O ('crane', 'acute')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'adage')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'adapt')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'adept')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'admin')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'admit')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'adobe')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'adopt')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'adore')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'adorn')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'adult')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'affix')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'afire')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'afoot')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'afoul')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'after')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'again')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'agape')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'agate')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'agent')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'agile')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'aging')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'aglow')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'agony')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'agora')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'agree')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'ahead')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'aider')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'aisle')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'alarm')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'album')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'alert')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'algae')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'alibi')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'alien')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'align')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'alike')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'alive')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'allay')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'alley')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'allot')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'allow')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'alloy')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'aloft')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'alone')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'along')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'aloof')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'aloud')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'alpha')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'altar')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'alter')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'amass')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'amaze')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'amber')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'amble')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'amend')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'amiss')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'amity')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'among')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'ample')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'amply')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'amuse')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'angel')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'anger')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'angle')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'angry')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'angst')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'anime')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'ankle')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'annex')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'annoy')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'annul')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'anode')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'antic')
# ('r', 'n') O ('crane', 'antic')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'anvil')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'aorta')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'apart')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'aphid')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'aping')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'apnea')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'apple')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'apply')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'apron')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'aptly')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'arbor')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'ardor')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'arena')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'argue')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'arise')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'armor')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'aroma')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'arose')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'array')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'arrow')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'arson')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'artsy')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'ascot')
# ('r', 's') O ('crane', 'ascot')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'ashen')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'aside')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'askew')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'assay')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'asset')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'atoll')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'atone')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'attic')
# ('r', 't') O ('crane', 'attic')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'audio')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'audit')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'augur')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'aunty')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'avail')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'avert')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'avian')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'avoid')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'await')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'awake')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'award')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'aware')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'awash')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'awful')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'awoke')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'axial')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'axiom')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'axion')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'azure')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bacon')
# ('r', 'a') O ('crane', 'bacon')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'badge')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'badly')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bagel')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'baggy')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'baker')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'baler')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'balmy')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'banal')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'banjo')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'barge')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'baron')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'basal')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'basic')
# ('r', 'a') O ('crane', 'basic')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'basil')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'basin')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'basis')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'baste')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'batch')
# ('r', 'a') O ('crane', 'batch')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bathe')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'baton')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'batty')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bawdy')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bayou')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'beach')
# ('r', 'e') O ('crane', 'beach')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'beady')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'beard')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'beast')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'beech')
# ('r', 'e') O ('crane', 'beech')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'beefy')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'befit')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'began')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'begat')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'beget')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'begin')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'begun')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'being')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'belch')
# ('r', 'e') O ('crane', 'belch')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'belie')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'belle')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'belly')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'below')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bench')
# ('r', 'e') O ('crane', 'bench')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'beret')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'berry')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'berth')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'beset')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'betel')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bevel')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bezel')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bible')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bicep')
# ('r', 'i') O ('crane', 'bicep')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'biddy')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bigot')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bilge')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'billy')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'binge')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bingo')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'biome')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'birch')
# ('r', 'i') O ('crane', 'birch')
# ('a', 'r') - ('crane', 'birch')
# ('n', 'c') - ('crane', 'birch')
# ('e', 'h') O ('crane', 'birch')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'birth')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bison')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bitty')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'black')
# ('r', 'l') O ('crane', 'black')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'blade')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'blame')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bland')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'blank')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'blare')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'blast')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'blaze')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bleak')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bleat')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bleed')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bleep')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'blend')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bless')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'blimp')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'blind')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'blink')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bliss')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'blitz')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bloat')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'block')
# ('r', 'l') O ('crane', 'block')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bloke')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'blond')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'blood')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bloom')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'blown')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bluer')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bluff')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'blunt')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'blurb')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'blurt')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'blush')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'board')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'boast')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bobby')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'boney')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bongo')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bonus')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'booby')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'boost')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'booth')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'booty')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'booze')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'boozy')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'borax')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'borne')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bosom')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bossy')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'botch')
# ('r', 'o') O ('crane', 'botch')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bough')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'boule')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bound')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bowel')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'boxer')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'brace')
# ('r', 'r') O ('crane', 'brace')
#    l1 == l2 and t != 'X':
# ('c', 'b') O ('crane', 'braid')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'brain')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'brake')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'brand')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'brash')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'brass')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'brave')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bravo')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'brawl')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'brawn')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bread')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'break')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'breed')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'briar')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bribe')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'brick')
# ('r', 'r') O ('crane', 'brick')
#    l1 == l2 and t != 'X':
# ('c', 'b') O ('crane', 'bride')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'brief')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'brine')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bring')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'brink')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'briny')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'brisk')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'broad')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'broil')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'broke')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'brood')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'brook')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'broom')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'broth')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'brown')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'brunt')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'brush')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'brute')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'buddy')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'budge')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'buggy')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bugle')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'build')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'built')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bulge')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bulky')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bully')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bunch')
# ('r', 'u') O ('crane', 'bunch')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bunny')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'burly')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'burnt')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'burst')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bused')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bushy')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'butch')
# ('r', 'u') O ('crane', 'butch')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'butte')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'buxom')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'buyer')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bylaw')
#    l1 not in candidate and t == 'O':
# ('c', 'c') O ('crane', 'cabal')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cabby')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cabin')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cable')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cacao')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cache')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cacti')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'caddy')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cadet')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cagey')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cairn')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'camel')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cameo')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'canal')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'candy')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'canny')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'canoe')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'canon')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'caper')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'caput')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'carat')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cargo')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'carol')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'carry')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'carve')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'caste')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'catch')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cater')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'catty')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'caulk')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cause')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cavil')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cease')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cedar')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cello')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'chafe')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'chaff')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'chain')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'chair')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'chalk')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'champ')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'chant')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'chaos')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'chard')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'charm')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'chart')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'chase')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'chasm')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cheap')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cheat')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'check')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cheek')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cheer')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'chess')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'chest')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'chick')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'chide')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'chief')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'child')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'chili')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'chill')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'chime')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'china')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'chirp')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'chock')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'choir')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'choke')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'chord')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'chore')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'chose')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'chuck')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'chump')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'chunk')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'churn')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'chute')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cider')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cigar')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cinch')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'circa')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'civic')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'civil')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'clack')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'claim')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'clamp')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'clang')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'clank')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'clash')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'clasp')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'class')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'clean')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'clear')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cleat')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cleft')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'clerk')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'click')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cliff')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'climb')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cling')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'clink')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cloak')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'clock')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'clone')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'close')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cloth')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cloud')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'clout')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'clove')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'clown')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cluck')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'clued')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'clump')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'clung')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'coach')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'coast')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cobra')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cocoa')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'colon')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'color')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'comet')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'comfy')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'comic')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'comma')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'conch')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'condo')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'conic')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'copse')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'coral')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'corer')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'corny')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'couch')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cough')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'could')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'count')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'coupe')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'court')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'coven')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cover')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'covet')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'covey')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cower')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'coyly')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crack')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'craft')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cramp')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crane')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crank')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crash')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crass')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crate')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crave')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crawl')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'craze')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crazy')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'creak')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cream')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'credo')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'creed')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'creek')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'creep')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'creme')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crepe')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crept')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cress')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crest')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crick')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cried')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crier')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crime')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crimp')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crisp')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'croak')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crock')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crone')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crony')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crook')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cross')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'croup')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crowd')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crown')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crude')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cruel')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crumb')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crump')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crush')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crust')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crypt')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cubic')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cumin')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'curio')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'curly')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'curry')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'curse')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'curve')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'curvy')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cutie')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cyber')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cycle')
#    l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cynic')
#    l1 == l2 and t != 'X':
# ('c', 'd') O ('crane', 'daddy')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'daily')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dairy')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'daisy')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dally')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dance')
# ('r', 'a') O ('crane', 'dance')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dandy')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'datum')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'daunt')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dealt')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'death')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'debar')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'debit')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'debug')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'debut')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'decal')
# ('r', 'e') O ('crane', 'decal')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'decay')
# ('r', 'e') O ('crane', 'decay')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'decor')
# ('r', 'e') O ('crane', 'decor')
# ('a', 'c') - ('crane', 'decor')
# ('n', 'o') - ('crane', 'decor')
# ('e', 'r') O ('crane', 'decor')
# ('c', 'd') O ('crane', 'decoy')
# ('r', 'e') O ('crane', 'decoy')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'decry')
# ('r', 'e') O ('crane', 'decry')
# ('a', 'c') - ('crane', 'decry')
# ('n', 'r') - ('crane', 'decry')
# ('e', 'y') O ('crane', 'decry')
# ('c', 'd') O ('crane', 'defer')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'deign')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'deity')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'delay')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'delta')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'delve')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'demon')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'demur')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'denim')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dense')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'depot')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'depth')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'derby')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'deter')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'detox')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'deuce')
# ('r', 'e') O ('crane', 'deuce')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'devil')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'diary')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dicey')
# ('r', 'i') O ('crane', 'dicey')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'digit')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dilly')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dimly')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'diner')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dingo')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dingy')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'diode')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dirge')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dirty')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'disco')
# ('r', 'i') O ('crane', 'disco')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'ditch')
# ('r', 'i') O ('crane', 'ditch')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'ditto')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'ditty')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'diver')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dizzy')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dodge')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dodgy')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dogma')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'doing')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dolly')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'donor')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'donut')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dopey')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'doubt')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dough')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dowdy')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dowel')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'downy')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dowry')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dozen')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'draft')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'drain')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'drake')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'drama')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'drank')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'drape')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'drawl')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'drawn')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dread')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dream')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dress')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dried')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'drier')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'drift')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'drill')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'drink')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'drive')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'droit')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'droll')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'drone')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'drool')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'droop')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dross')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'drove')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'drown')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'druid')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'drunk')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dryer')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dryly')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'duchy')
# ('r', 'u') O ('crane', 'duchy')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dully')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dummy')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dumpy')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dunce')
# ('r', 'u') O ('crane', 'dunce')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dusky')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dusty')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dutch')
# ('r', 'u') O ('crane', 'dutch')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'duvet')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dwarf')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dwell')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dwelt')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dying')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'eager')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'eagle')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'early')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'earth')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'easel')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'eaten')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'eater')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'ebony')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'eclat')
# ('r', 'c') O ('crane', 'eclat')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'edict')
# ('r', 'd') O ('crane', 'edict')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'edify')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'eerie')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'egret')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'eight')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'eject')
# ('r', 'j') O ('crane', 'eject')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'eking')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'elate')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'elbow')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'elder')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'elect')
# ('r', 'l') O ('crane', 'elect')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'elegy')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'elfin')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'elide')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'elite')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'elope')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'elude')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'email')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'embed')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'ember')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'emcee')
# ('r', 'm') O ('crane', 'emcee')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'empty')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'enact')
# ('r', 'n') O ('crane', 'enact')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'endow')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'enema')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'enemy')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'enjoy')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'ennui')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'ensue')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'enter')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'entry')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'envoy')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'epoch')
# ('r', 'p') O ('crane', 'epoch')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'epoxy')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'equal')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'equip')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'erase')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'erect')
# ('r', 'r') O ('crane', 'erect')
#    l1 == l2 and t != 'X':
# ('c', 'e') O ('crane', 'erode')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'error')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'erupt')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'essay')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'ester')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'ether')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'ethic')
# ('r', 't') O ('crane', 'ethic')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'ethos')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'etude')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'evade')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'event')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'every')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'evict')
# ('r', 'v') O ('crane', 'evict')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'evoke')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'exact')
# ('r', 'x') O ('crane', 'exact')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'exalt')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'excel')
# ('r', 'x') O ('crane', 'excel')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'exert')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'exile')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'exist')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'expel')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'extol')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'extra')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'exult')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'eying')
#    l1 not in candidate and t == 'O':
# ('c', 'f') O ('crane', 'fable')
#    l1 not in candidate and t == 'O':
# ('c', 'f') O ('crane', 'facet')
# ('r', 'a') O ('crane', 'facet')
#    l1 not in candidate and t == 'O':
# ('c', 'f') O ('crane', 'faint')
#    l1 not in candidate and t == 'O':
# ('c', 'f') O ('crane', 'fairy')
#    l1 not in candidate and t == 'O':
# ('c', 'f') O ('crane', 'faith')
#    l1 not in candidate and t == 'O':
# ...
# ('r', 'r') O ('crane', 'trice')
#    l1 == l2 and t != 'X':
# ('c', 't') O ('crane', 'trick')
# ('r', 'r') O ('crane', 'trick')
#    l1 == l2 and t != 'X':
# ('c', 't') O ('crane', 'tried')
#    l1 not in candidate and t == 'O':
# ('c', 't') O ('crane', 'tripe')
#    l1 not in candidate and t == 'O':
# ('c', 't') O ('crane', 'trite')
#    l1 not in candidate and t == 'O':
# ('c', 't') O ('crane', 'troll')
#    l1 not in candidate and t == 'O':
# ('c', 't') O ('crane', 'troop')
#    l1 not in candidate and t == 'O':
# ('c', 't') O ('crane', 'trope')
#    l1 not in candidate and t == 'O':
# ('c', 't') O ('crane', 'trout')
#    l1 not in candidate and t == 'O':
# ('c', 't') O ('crane', 'trove')
#    l1 not in candidate and t == 'O':
# ('c', 't') O ('crane', 'truce')
# ('r', 'r') O ('crane', 'truce')
#    l1 == l2 and t != 'X':
# ('c', 't') O ('crane', 'truck')
# ('r', 'r') O ('crane', 'truck')
#    l1 == l2 and t != 'X':
# ('c', 't') O ('crane', 'truer')
#    l1 not in candidate and t == 'O':
# ('c', 't') O ('crane', 'truly')
#    l1 not in candidate and t == 'O':
# ('c', 't') O ('crane', 'trump')
#    l1 not in candidate and t == 'O':
# ('c', 't') O ('crane', 'trunk')
#    l1 not in candidate and t == 'O':
# ('c', 't') O ('crane', 'truss')
#    l1 not in candidate and t == 'O':
# ('c', 't') O ('crane', 'trust')
#    l1 not in candidate and t == 'O':
# ('c', 't') O ('crane', 'truth')
#    l1 not in candidate and t == 'O':
# ('c', 't') O ('crane', 'tryst')
#    l1 not in candidate and t == 'O':
# ('c', 't') O ('crane', 'tubal')
#    l1 not in candidate and t == 'O':
# ('c', 't') O ('crane', 'tuber')
#    l1 not in candidate and t == 'O':
# ('c', 't') O ('crane', 'tulip')
#    l1 not in candidate and t == 'O':
# ('c', 't') O ('crane', 'tulle')
#    l1 not in candidate and t == 'O':
# ('c', 't') O ('crane', 'tumor')
#    l1 not in candidate and t == 'O':
# ('c', 't') O ('crane', 'tunic')
# ('r', 'u') O ('crane', 'tunic')
#    l1 not in candidate and t == 'O':
# ('c', 't') O ('crane', 'turbo')
#    l1 not in candidate and t == 'O':
# ('c', 't') O ('crane', 'tutor')
#    l1 not in candidate and t == 'O':
# ('c', 't') O ('crane', 'twang')
#    l1 not in candidate and t == 'O':
# ('c', 't') O ('crane', 'tweak')
#    l1 not in candidate and t == 'O':
# ('c', 't') O ('crane', 'tweed')
#    l1 not in candidate and t == 'O':
# ('c', 't') O ('crane', 'tweet')
#    l1 not in candidate and t == 'O':
# ('c', 't') O ('crane', 'twice')
# ('r', 'w') O ('crane', 'twice')
#    l1 not in candidate and t == 'O':
# ('c', 't') O ('crane', 'twine')
#    l1 not in candidate and t == 'O':
# ('c', 't') O ('crane', 'twirl')
#    l1 not in candidate and t == 'O':
# ('c', 't') O ('crane', 'twist')
#    l1 not in candidate and t == 'O':
# ('c', 't') O ('crane', 'twixt')
#    l1 not in candidate and t == 'O':
# ('c', 't') O ('crane', 'tying')
#    l1 not in candidate and t == 'O':
# ('c', 'u') O ('crane', 'udder')
#    l1 not in candidate and t == 'O':
# ('c', 'u') O ('crane', 'ulcer')
# ('r', 'l') O ('crane', 'ulcer')
# ('a', 'c') - ('crane', 'ulcer')
# ('n', 'e') - ('crane', 'ulcer')
# ('e', 'r') O ('crane', 'ulcer')
# ('c', 'u') O ('crane', 'ultra')
#    l1 not in candidate and t == 'O':
# ('c', 'u') O ('crane', 'umbra')
#    l1 not in candidate and t == 'O':
# ('c', 'u') O ('crane', 'uncle')
# ('r', 'n') O ('crane', 'uncle')
#    l1 not in candidate and t == 'O':
# ('c', 'u') O ('crane', 'uncut')
# ('r', 'n') O ('crane', 'uncut')
#    l1 not in candidate and t == 'O':
# ('c', 'u') O ('crane', 'under')
#    l1 not in candidate and t == 'O':
# ('c', 'u') O ('crane', 'undid')
#    l1 not in candidate and t == 'O':
# ('c', 'u') O ('crane', 'undue')
#    l1 not in candidate and t == 'O':
# ('c', 'u') O ('crane', 'unfed')
#    l1 not in candidate and t == 'O':
# ('c', 'u') O ('crane', 'unfit')
#    l1 not in candidate and t == 'O':
# ('c', 'u') O ('crane', 'unify')
#    l1 not in candidate and t == 'O':
# ('c', 'u') O ('crane', 'union')
#    l1 not in candidate and t == 'O':
# ('c', 'u') O ('crane', 'unite')
#    l1 not in candidate and t == 'O':
# ('c', 'u') O ('crane', 'unity')
#    l1 not in candidate and t == 'O':
# ('c', 'u') O ('crane', 'unlit')
#    l1 not in candidate and t == 'O':
# ('c', 'u') O ('crane', 'unmet')
#    l1 not in candidate and t == 'O':
# ('c', 'u') O ('crane', 'unset')
#    l1 not in candidate and t == 'O':
# ('c', 'u') O ('crane', 'untie')
#    l1 not in candidate and t == 'O':
# ('c', 'u') O ('crane', 'until')
#    l1 not in candidate and t == 'O':
# ('c', 'u') O ('crane', 'unwed')
#    l1 not in candidate and t == 'O':
# ('c', 'u') O ('crane', 'unzip')
#    l1 not in candidate and t == 'O':
# ('c', 'u') O ('crane', 'upper')
#    l1 not in candidate and t == 'O':
# ('c', 'u') O ('crane', 'upset')
#    l1 not in candidate and t == 'O':
# ('c', 'u') O ('crane', 'urban')
#    l1 not in candidate and t == 'O':
# ('c', 'u') O ('crane', 'urine')
#    l1 not in candidate and t == 'O':
# ('c', 'u') O ('crane', 'usage')
#    l1 not in candidate and t == 'O':
# ('c', 'u') O ('crane', 'usher')
#    l1 not in candidate and t == 'O':
# ('c', 'u') O ('crane', 'using')
#    l1 not in candidate and t == 'O':
# ('c', 'u') O ('crane', 'usual')
#    l1 not in candidate and t == 'O':
# ('c', 'u') O ('crane', 'usurp')
#    l1 not in candidate and t == 'O':
# ('c', 'u') O ('crane', 'utile')
#    l1 not in candidate and t == 'O':
# ('c', 'u') O ('crane', 'utter')
#    l1 not in candidate and t == 'O':
# ('c', 'v') O ('crane', 'vague')
#    l1 not in candidate and t == 'O':
# ('c', 'v') O ('crane', 'valet')
#    l1 not in candidate and t == 'O':
# ('c', 'v') O ('crane', 'valid')
#    l1 not in candidate and t == 'O':
# ('c', 'v') O ('crane', 'valor')
#    l1 not in candidate and t == 'O':
# ('c', 'v') O ('crane', 'value')
#    l1 not in candidate and t == 'O':
# ('c', 'v') O ('crane', 'valve')
#    l1 not in candidate and t == 'O':
# ('c', 'v') O ('crane', 'vapid')
#    l1 not in candidate and t == 'O':
# ('c', 'v') O ('crane', 'vapor')
#    l1 not in candidate and t == 'O':
# ('c', 'v') O ('crane', 'vault')
#    l1 not in candidate and t == 'O':
# ('c', 'v') O ('crane', 'vaunt')
#    l1 not in candidate and t == 'O':
# ('c', 'v') O ('crane', 'vegan')
#    l1 not in candidate and t == 'O':
# ('c', 'v') O ('crane', 'venom')
#    l1 not in candidate and t == 'O':
# ('c', 'v') O ('crane', 'venue')
#    l1 not in candidate and t == 'O':
# ('c', 'v') O ('crane', 'verge')
#    l1 not in candidate and t == 'O':
# ('c', 'v') O ('crane', 'verse')
#    l1 not in candidate and t == 'O':
# ('c', 'v') O ('crane', 'verso')
#    l1 not in candidate and t == 'O':
# ('c', 'v') O ('crane', 'verve')
#    l1 not in candidate and t == 'O':
# ('c', 'v') O ('crane', 'vicar')
# ('r', 'i') O ('crane', 'vicar')
# ('a', 'c') - ('crane', 'vicar')
#    l1 in candidate and t == '-':
# ('c', 'v') O ('crane', 'video')
#    l1 not in candidate and t == 'O':
# ('c', 'v') O ('crane', 'vigil')
#    l1 not in candidate and t == 'O':
# ('c', 'v') O ('crane', 'vigor')
#    l1 not in candidate and t == 'O':
# ('c', 'v') O ('crane', 'villa')
#    l1 not in candidate and t == 'O':
# ('c', 'v') O ('crane', 'vinyl')
#    l1 not in candidate and t == 'O':
# ('c', 'v') O ('crane', 'viola')
#    l1 not in candidate and t == 'O':
# ('c', 'v') O ('crane', 'viper')
#    l1 not in candidate and t == 'O':
# ('c', 'v') O ('crane', 'viral')
#    l1 not in candidate and t == 'O':
# ('c', 'v') O ('crane', 'virus')
#    l1 not in candidate and t == 'O':
# ('c', 'v') O ('crane', 'visit')
#    l1 not in candidate and t == 'O':
# ('c', 'v') O ('crane', 'visor')
#    l1 not in candidate and t == 'O':
# ('c', 'v') O ('crane', 'vista')
#    l1 not in candidate and t == 'O':
# ('c', 'v') O ('crane', 'vital')
#    l1 not in candidate and t == 'O':
# ('c', 'v') O ('crane', 'vivid')
#    l1 not in candidate and t == 'O':
# ('c', 'v') O ('crane', 'vixen')
#    l1 not in candidate and t == 'O':
# ('c', 'v') O ('crane', 'vocal')
# ('r', 'o') O ('crane', 'vocal')
#    l1 not in candidate and t == 'O':
# ('c', 'v') O ('crane', 'vodka')
#    l1 not in candidate and t == 'O':
# ('c', 'v') O ('crane', 'vogue')
#    l1 not in candidate and t == 'O':
# ('c', 'v') O ('crane', 'voice')
# ('r', 'o') O ('crane', 'voice')
#    l1 not in candidate and t == 'O':
# ('c', 'v') O ('crane', 'voila')
#    l1 not in candidate and t == 'O':
# ('c', 'v') O ('crane', 'vomit')
#    l1 not in candidate and t == 'O':
# ('c', 'v') O ('crane', 'voter')
#    l1 not in candidate and t == 'O':
# ('c', 'v') O ('crane', 'vouch')
# ('r', 'o') O ('crane', 'vouch')
#    l1 not in candidate and t == 'O':
# ('c', 'v') O ('crane', 'vowel')
#    l1 not in candidate and t == 'O':
# ('c', 'v') O ('crane', 'vying')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'wacky')
# ('r', 'a') O ('crane', 'wacky')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'wafer')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'wager')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'wagon')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'waist')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'waive')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'waltz')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'warty')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'waste')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'watch')
# ('r', 'a') O ('crane', 'watch')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'water')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'waver')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'waxen')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'weary')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'weave')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'wedge')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'weedy')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'weigh')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'weird')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'welch')
# ('r', 'e') O ('crane', 'welch')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'welsh')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'wench')
# ('r', 'e') O ('crane', 'wench')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'whack')
# ('r', 'h') O ('crane', 'whack')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'whale')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'wharf')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'wheat')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'wheel')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'whelp')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'where')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'which')
# ('r', 'h') O ('crane', 'which')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'whiff')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'while')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'whine')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'whiny')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'whirl')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'whisk')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'white')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'whole')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'whoop')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'whose')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'widen')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'wider')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'widow')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'width')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'wield')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'wight')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'willy')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'wimpy')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'wince')
# ('r', 'i') O ('crane', 'wince')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'winch')
# ('r', 'i') O ('crane', 'winch')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'windy')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'wiser')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'wispy')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'witch')
# ('r', 'i') O ('crane', 'witch')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'witty')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'woken')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'woman')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'women')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'woody')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'wooer')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'wooly')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'woozy')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'wordy')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'world')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'worry')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'worse')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'worst')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'worth')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'would')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'wound')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'woven')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'wrack')
# ('r', 'r') O ('crane', 'wrack')
#    l1 == l2 and t != 'X':
# ('c', 'w') O ('crane', 'wrath')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'wreak')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'wreck')
# ('r', 'r') O ('crane', 'wreck')
#    l1 == l2 and t != 'X':
# ('c', 'w') O ('crane', 'wrest')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'wring')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'wrist')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'write')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'wrong')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'wrote')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'wrung')
#    l1 not in candidate and t == 'O':
# ('c', 'w') O ('crane', 'wryly')
#    l1 not in candidate and t == 'O':
# ('c', 'y') O ('crane', 'yacht')
# ('r', 'a') O ('crane', 'yacht')
#    l1 not in candidate and t == 'O':
# ('c', 'y') O ('crane', 'yearn')
#    l1 not in candidate and t == 'O':
# ('c', 'y') O ('crane', 'yeast')
#    l1 not in candidate and t == 'O':
# ('c', 'y') O ('crane', 'yield')
#    l1 not in candidate and t == 'O':
# ('c', 'y') O ('crane', 'young')
#    l1 not in candidate and t == 'O':
# ('c', 'y') O ('crane', 'youth')
#    l1 not in candidate and t == 'O':
# ('c', 'z') O ('crane', 'zebra')
#    l1 not in candidate and t == 'O':
# ('c', 'z') O ('crane', 'zesty')
#    l1 not in candidate and t == 'O':
# ('c', 'z') O ('crane', 'zonal')
#    l1 not in candidate and t == 'O':
# ('p', 'd') - ('perch', 'decor')
# ('e', 'e') O ('perch', 'decor')
#    l1 == l2 and t != 'X':
# ('p', 'd') - ('perch', 'decry')
# ('e', 'e') O ('perch', 'decry')
#    l1 == l2 and t != 'X':
# ('p', 'm') - ('perch', 'mercy')
# ('e', 'e') O ('perch', 'mercy')
#    l1 == l2 and t != 'X':
# ('p', 'p') - ('perch', 'perch')
#    l1 == l2 and t != 'X':
# ('p', 'r') - ('perch', 'recur')
# ('e', 'e') O ('perch', 'recur')
#    l1 == l2 and t != 'X':
# ('p', 'r') - ('perch', 'recut')
# ('e', 'e') O ('perch', 'recut')
#    l1 == l2 and t != 'X':
# ('p', 'r') - ('perch', 'relic')
# ('e', 'e') O ('perch', 'relic')
#    l1 == l2 and t != 'X':
# ('p', 'r') - ('perch', 'retch')
# ('e', 'e') O ('perch', 'retch')
#    l1 == l2 and t != 'X':
# ('p', 's') - ('perch', 'screw')
# ('e', 'c') O ('perch', 'screw')
# ('r', 'r') O ('perch', 'screw')
#    l1 == l2 and t != 'X':
# ('p', 'u') - ('perch', 'ulcer')
# ('e', 'l') O ('perch', 'ulcer')
# ('r', 'c') O ('perch', 'ulcer')
# ('c', 'e') O ('perch', 'ulcer')
# ('h', 'r') - ('perch', 'ulcer')
# ['ulcer']

# %%
narrow = []
for pos in answers:
    good = True
    for l1, l2 in zip("crane", pos):
        if l1 == "c" and (l1 == l2 or l1 not in pos):
            good = False
            break
        if l1 == "r" and (l1 == l2 or l1 not in pos):
            good = False
            break
        if l1 == "e" and (l1 == l2 or l1 not in pos):
            good = False
            break
        if l2 == "a":
            good = False
            break
        if l2 == "n":
            good = False
            break
    if good:
        narrow += [pos]

# %%
def make_template(pred, gold):
    template = ""
    for l1, l2 in zip(pred, gold):
        if l1 == l2:
            template += "X"
        elif l1 in gold:
            template += "O"
        else:
            template += "-"
    return template

# %%
answers_left = narrow_down('crane', 'OO--O', answers)
allowed_left = narrow_down('crane', 'OO--O', allowed)
# Out:
# ('c', 'a') O ('crane', 'aback')
# ('r', 'b') O ('crane', 'aback')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'abase')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'abate')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'abbey')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'abbot')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'abhor')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'abide')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'abled')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'abode')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'abort')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'about')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'above')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'abuse')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'abyss')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'acorn')
# ('r', 'c') O ('crane', 'acorn')
# ('a', 'o') - ('crane', 'acorn')
#    l1 in candidate and t != 'O':
# ('c', 'a') O ('crane', 'acrid')
# ('r', 'c') O ('crane', 'acrid')
# ('a', 'r') - ('crane', 'acrid')
#    l1 in candidate and t != 'O':
# ('c', 'a') O ('crane', 'actor')
# ('r', 'c') O ('crane', 'actor')
# ('a', 't') - ('crane', 'actor')
#    l1 in candidate and t != 'O':
# ('c', 'a') O ('crane', 'acute')
# ('r', 'c') O ('crane', 'acute')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'adage')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'adapt')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'adept')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'admin')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'admit')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'adobe')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'adopt')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'adore')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'adorn')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'adult')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'affix')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'afire')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'afoot')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'afoul')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'after')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'again')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'agape')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'agate')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'agent')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'agile')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'aging')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'aglow')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'agony')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'agora')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'agree')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'ahead')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'aider')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'aisle')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'alarm')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'album')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'alert')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'algae')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'alibi')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'alien')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'align')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'alike')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'alive')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'allay')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'alley')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'allot')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'allow')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'alloy')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'aloft')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'alone')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'along')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'aloof')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'aloud')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'alpha')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'altar')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'alter')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'amass')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'amaze')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'amber')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'amble')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'amend')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'amiss')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'amity')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'among')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'ample')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'amply')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'amuse')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'angel')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'anger')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'angle')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'angry')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'angst')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'anime')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'ankle')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'annex')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'annoy')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'annul')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'anode')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'antic')
# ('r', 'n') O ('crane', 'antic')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'anvil')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'aorta')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'apart')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'aphid')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'aping')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'apnea')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'apple')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'apply')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'apron')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'aptly')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'arbor')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'ardor')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'arena')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'argue')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'arise')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'armor')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'aroma')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'arose')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'array')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'arrow')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'arson')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'artsy')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'ascot')
# ('r', 's') O ('crane', 'ascot')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'ashen')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'aside')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'askew')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'assay')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'asset')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'atoll')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'atone')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'attic')
# ('r', 't') O ('crane', 'attic')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'audio')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'audit')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'augur')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'aunty')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'avail')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'avert')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'avian')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'avoid')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'await')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'awake')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'award')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'aware')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'awash')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'awful')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'awoke')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'axial')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'axiom')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'axion')
#    l1 not in candidate and t == 'O':
# ('c', 'a') O ('crane', 'azure')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bacon')
# ('r', 'a') O ('crane', 'bacon')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'badge')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'badly')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bagel')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'baggy')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'baker')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'baler')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'balmy')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'banal')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'banjo')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'barge')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'baron')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'basal')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'basic')
# ('r', 'a') O ('crane', 'basic')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'basil')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'basin')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'basis')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'baste')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'batch')
# ('r', 'a') O ('crane', 'batch')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bathe')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'baton')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'batty')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bawdy')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bayou')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'beach')
# ('r', 'e') O ('crane', 'beach')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'beady')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'beard')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'beast')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'beech')
# ('r', 'e') O ('crane', 'beech')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'beefy')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'befit')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'began')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'begat')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'beget')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'begin')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'begun')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'being')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'belch')
# ('r', 'e') O ('crane', 'belch')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'belie')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'belle')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'belly')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'below')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bench')
# ('r', 'e') O ('crane', 'bench')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'beret')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'berry')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'berth')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'beset')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'betel')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bevel')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bezel')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bible')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bicep')
# ('r', 'i') O ('crane', 'bicep')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'biddy')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bigot')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bilge')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'billy')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'binge')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bingo')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'biome')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'birch')
# ('r', 'i') O ('crane', 'birch')
# ('a', 'r') - ('crane', 'birch')
# ('n', 'c') - ('crane', 'birch')
# ('e', 'h') O ('crane', 'birch')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'birth')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bison')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bitty')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'black')
# ('r', 'l') O ('crane', 'black')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'blade')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'blame')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bland')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'blank')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'blare')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'blast')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'blaze')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bleak')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bleat')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bleed')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bleep')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'blend')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bless')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'blimp')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'blind')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'blink')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bliss')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'blitz')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bloat')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'block')
# ('r', 'l') O ('crane', 'block')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bloke')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'blond')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'blood')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bloom')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'blown')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bluer')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bluff')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'blunt')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'blurb')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'blurt')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'blush')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'board')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'boast')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bobby')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'boney')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bongo')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bonus')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'booby')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'boost')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'booth')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'booty')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'booze')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'boozy')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'borax')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'borne')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bosom')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bossy')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'botch')
# ('r', 'o') O ('crane', 'botch')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bough')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'boule')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bound')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bowel')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'boxer')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'brace')
# ('r', 'r') O ('crane', 'brace')
#    if l1 == l2 and t != 'X':
# ('c', 'b') O ('crane', 'braid')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'brain')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'brake')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'brand')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'brash')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'brass')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'brave')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bravo')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'brawl')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'brawn')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bread')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'break')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'breed')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'briar')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bribe')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'brick')
# ('r', 'r') O ('crane', 'brick')
#    if l1 == l2 and t != 'X':
# ('c', 'b') O ('crane', 'bride')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'brief')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'brine')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bring')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'brink')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'briny')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'brisk')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'broad')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'broil')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'broke')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'brood')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'brook')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'broom')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'broth')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'brown')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'brunt')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'brush')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'brute')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'buddy')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'budge')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'buggy')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bugle')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'build')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'built')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bulge')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bulky')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bully')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bunch')
# ('r', 'u') O ('crane', 'bunch')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bunny')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'burly')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'burnt')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'burst')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bused')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bushy')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'butch')
# ('r', 'u') O ('crane', 'butch')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'butte')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'buxom')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'buyer')
#    l1 not in candidate and t == 'O':
# ('c', 'b') O ('crane', 'bylaw')
#    l1 not in candidate and t == 'O':
# ('c', 'c') O ('crane', 'cabal')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cabby')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cabin')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cable')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cacao')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cache')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cacti')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'caddy')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cadet')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cagey')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cairn')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'camel')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cameo')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'canal')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'candy')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'canny')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'canoe')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'canon')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'caper')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'caput')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'carat')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cargo')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'carol')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'carry')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'carve')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'caste')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'catch')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cater')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'catty')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'caulk')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cause')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cavil')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cease')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cedar')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cello')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'chafe')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'chaff')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'chain')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'chair')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'chalk')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'champ')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'chant')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'chaos')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'chard')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'charm')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'chart')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'chase')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'chasm')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cheap')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cheat')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'check')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cheek')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cheer')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'chess')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'chest')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'chick')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'chide')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'chief')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'child')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'chili')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'chill')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'chime')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'china')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'chirp')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'chock')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'choir')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'choke')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'chord')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'chore')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'chose')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'chuck')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'chump')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'chunk')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'churn')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'chute')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cider')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cigar')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cinch')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'circa')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'civic')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'civil')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'clack')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'claim')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'clamp')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'clang')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'clank')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'clash')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'clasp')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'class')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'clean')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'clear')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cleat')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cleft')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'clerk')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'click')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cliff')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'climb')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cling')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'clink')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cloak')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'clock')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'clone')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'close')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cloth')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cloud')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'clout')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'clove')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'clown')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cluck')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'clued')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'clump')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'clung')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'coach')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'coast')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cobra')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cocoa')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'colon')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'color')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'comet')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'comfy')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'comic')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'comma')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'conch')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'condo')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'conic')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'copse')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'coral')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'corer')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'corny')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'couch')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cough')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'could')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'count')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'coupe')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'court')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'coven')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cover')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'covet')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'covey')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cower')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'coyly')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crack')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'craft')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cramp')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crane')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crank')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crash')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crass')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crate')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crave')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crawl')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'craze')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crazy')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'creak')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cream')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'credo')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'creed')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'creek')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'creep')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'creme')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crepe')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crept')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cress')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crest')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crick')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cried')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crier')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crime')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crimp')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crisp')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'croak')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crock')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crone')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crony')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crook')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cross')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'croup')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crowd')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crown')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crude')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cruel')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crumb')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crump')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crush')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crust')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'crypt')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cubic')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cumin')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'curio')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'curly')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'curry')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'curse')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'curve')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'curvy')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cutie')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cyber')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cycle')
#    if l1 == l2 and t != 'X':
# ('c', 'c') O ('crane', 'cynic')
#    if l1 == l2 and t != 'X':
# ('c', 'd') O ('crane', 'daddy')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'daily')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dairy')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'daisy')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dally')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dance')
# ('r', 'a') O ('crane', 'dance')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dandy')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'datum')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'daunt')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dealt')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'death')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'debar')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'debit')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'debug')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'debut')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'decal')
# ('r', 'e') O ('crane', 'decal')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'decay')
# ('r', 'e') O ('crane', 'decay')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'decor')
# ('r', 'e') O ('crane', 'decor')
# ('a', 'c') - ('crane', 'decor')
# ('n', 'o') - ('crane', 'decor')
# ('e', 'r') O ('crane', 'decor')
# ('c', 'd') O ('crane', 'decoy')
# ('r', 'e') O ('crane', 'decoy')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'decry')
# ('r', 'e') O ('crane', 'decry')
# ('a', 'c') - ('crane', 'decry')
# ('n', 'r') - ('crane', 'decry')
# ('e', 'y') O ('crane', 'decry')
# ('c', 'd') O ('crane', 'defer')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'deign')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'deity')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'delay')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'delta')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'delve')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'demon')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'demur')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'denim')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dense')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'depot')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'depth')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'derby')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'deter')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'detox')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'deuce')
# ('r', 'e') O ('crane', 'deuce')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'devil')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'diary')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dicey')
# ('r', 'i') O ('crane', 'dicey')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'digit')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dilly')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dimly')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'diner')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dingo')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dingy')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'diode')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dirge')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dirty')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'disco')
# ('r', 'i') O ('crane', 'disco')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'ditch')
# ('r', 'i') O ('crane', 'ditch')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'ditto')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'ditty')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'diver')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dizzy')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dodge')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dodgy')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dogma')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'doing')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dolly')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'donor')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'donut')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dopey')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'doubt')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dough')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dowdy')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dowel')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'downy')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dowry')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dozen')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'draft')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'drain')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'drake')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'drama')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'drank')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'drape')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'drawl')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'drawn')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dread')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dream')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dress')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dried')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'drier')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'drift')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'drill')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'drink')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'drive')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'droit')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'droll')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'drone')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'drool')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'droop')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dross')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'drove')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'drown')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'druid')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'drunk')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dryer')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dryly')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'duchy')
# ('r', 'u') O ('crane', 'duchy')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dully')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dummy')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dumpy')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dunce')
# ('r', 'u') O ('crane', 'dunce')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dusky')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dusty')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dutch')
# ('r', 'u') O ('crane', 'dutch')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'duvet')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dwarf')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dwell')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dwelt')
#    l1 not in candidate and t == 'O':
# ('c', 'd') O ('crane', 'dying')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'eager')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'eagle')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'early')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'earth')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'easel')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'eaten')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'eater')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'ebony')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'eclat')
# ('r', 'c') O ('crane', 'eclat')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'edict')
# ('r', 'd') O ('crane', 'edict')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'edify')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'eerie')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'egret')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'eight')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'eject')
# ('r', 'j') O ('crane', 'eject')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'eking')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'elate')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'elbow')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'elder')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'elect')
# ('r', 'l') O ('crane', 'elect')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'elegy')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'elfin')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'elide')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'elite')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'elope')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'elude')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'email')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'embed')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'ember')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'emcee')
# ('r', 'm') O ('crane', 'emcee')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'empty')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'enact')
# ('r', 'n') O ('crane', 'enact')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'endow')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'enema')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'enemy')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'enjoy')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'ennui')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'ensue')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'enter')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'entry')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'envoy')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'epoch')
# ('r', 'p') O ('crane', 'epoch')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'epoxy')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'equal')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'equip')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'erase')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'erect')
# ('r', 'r') O ('crane', 'erect')
#    if l1 == l2 and t != 'X':
# ('c', 'e') O ('crane', 'erode')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'error')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'erupt')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'essay')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'ester')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'ether')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'ethic')
# ('r', 't') O ('crane', 'ethic')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'ethos')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'etude')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'evade')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'event')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'every')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'evict')
# ('r', 'v') O ('crane', 'evict')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'evoke')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'exact')
# ('r', 'x') O ('crane', 'exact')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'exalt')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'excel')
# ('r', 'x') O ('crane', 'excel')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'exert')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'exile')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'exist')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'expel')
#    l1 not in candidate and t == 'O':
# ('c', 'e') O ('crane', 'extol')
# ...
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'scoot')
# ('r', 'c') O ('crane', 'scoot')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'scopa')
# ('r', 'c') O ('crane', 'scopa')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'scops')
# ('r', 'c') O ('crane', 'scops')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'scots')
# ('r', 'c') O ('crane', 'scots')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'scoug')
# ('r', 'c') O ('crane', 'scoug')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'scoup')
# ('r', 'c') O ('crane', 'scoup')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'scowp')
# ('r', 'c') O ('crane', 'scowp')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'scows')
# ('r', 'c') O ('crane', 'scows')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'scrab')
# ('r', 'c') O ('crane', 'scrab')
# ('a', 'r') - ('crane', 'scrab')
#    l1 in candidate and t != 'O':
# ('c', 's') O ('crane', 'scrae')
# ('r', 'c') O ('crane', 'scrae')
# ('a', 'r') - ('crane', 'scrae')
#    l1 in candidate and t != 'O':
# ('c', 's') O ('crane', 'scrag')
# ('r', 'c') O ('crane', 'scrag')
# ('a', 'r') - ('crane', 'scrag')
#    l1 in candidate and t != 'O':
# ('c', 's') O ('crane', 'scran')
# ('r', 'c') O ('crane', 'scran')
# ('a', 'r') - ('crane', 'scran')
#    l1 in candidate and t != 'O':
# ('c', 's') O ('crane', 'scrat')
# ('r', 'c') O ('crane', 'scrat')
# ('a', 'r') - ('crane', 'scrat')
#    l1 in candidate and t != 'O':
# ('c', 's') O ('crane', 'scraw')
# ('r', 'c') O ('crane', 'scraw')
# ('a', 'r') - ('crane', 'scraw')
#    l1 in candidate and t != 'O':
# ('c', 's') O ('crane', 'scray')
# ('r', 'c') O ('crane', 'scray')
# ('a', 'r') - ('crane', 'scray')
#    l1 in candidate and t != 'O':
# ('c', 's') O ('crane', 'scrim')
# ('r', 'c') O ('crane', 'scrim')
# ('a', 'r') - ('crane', 'scrim')
# ('n', 'i') - ('crane', 'scrim')
# ('e', 'm') O ('crane', 'scrim')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'scrip')
# ('r', 'c') O ('crane', 'scrip')
# ('a', 'r') - ('crane', 'scrip')
# ('n', 'i') - ('crane', 'scrip')
# ('e', 'p') O ('crane', 'scrip')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'scrob')
# ('r', 'c') O ('crane', 'scrob')
# ('a', 'r') - ('crane', 'scrob')
# ('n', 'o') - ('crane', 'scrob')
# ('e', 'b') O ('crane', 'scrob')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'scrod')
# ('r', 'c') O ('crane', 'scrod')
# ('a', 'r') - ('crane', 'scrod')
# ('n', 'o') - ('crane', 'scrod')
# ('e', 'd') O ('crane', 'scrod')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'scrog')
# ('r', 'c') O ('crane', 'scrog')
# ('a', 'r') - ('crane', 'scrog')
# ('n', 'o') - ('crane', 'scrog')
# ('e', 'g') O ('crane', 'scrog')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'scrow')
# ('r', 'c') O ('crane', 'scrow')
# ('a', 'r') - ('crane', 'scrow')
# ('n', 'o') - ('crane', 'scrow')
# ('e', 'w') O ('crane', 'scrow')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'scudi')
# ('r', 'c') O ('crane', 'scudi')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'scudo')
# ('r', 'c') O ('crane', 'scudo')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'scuds')
# ('r', 'c') O ('crane', 'scuds')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'scuff')
# ('r', 'c') O ('crane', 'scuff')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'scuft')
# ('r', 'c') O ('crane', 'scuft')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'scugs')
# ('r', 'c') O ('crane', 'scugs')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'sculk')
# ('r', 'c') O ('crane', 'sculk')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'scull')
# ('r', 'c') O ('crane', 'scull')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'sculp')
# ('r', 'c') O ('crane', 'sculp')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'sculs')
# ('r', 'c') O ('crane', 'sculs')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'scums')
# ('r', 'c') O ('crane', 'scums')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'scups')
# ('r', 'c') O ('crane', 'scups')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'scurf')
# ('r', 'c') O ('crane', 'scurf')
# ('a', 'u') - ('crane', 'scurf')
# ('n', 'r') - ('crane', 'scurf')
# ('e', 'f') O ('crane', 'scurf')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'scurs')
# ('r', 'c') O ('crane', 'scurs')
# ('a', 'u') - ('crane', 'scurs')
# ('n', 'r') - ('crane', 'scurs')
# ('e', 's') O ('crane', 'scurs')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'scuse')
# ('r', 'c') O ('crane', 'scuse')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'scuta')
# ('r', 'c') O ('crane', 'scuta')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'scute')
# ('r', 'c') O ('crane', 'scute')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'scuts')
# ('r', 'c') O ('crane', 'scuts')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'scuzz')
# ('r', 'c') O ('crane', 'scuzz')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'scyes')
# ('r', 'c') O ('crane', 'scyes')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'sdayn')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'sdein')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'seals')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'seame')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'seams')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'seamy')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'seans')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'seare')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'sears')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'sease')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'seats')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'seaze')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'sebum')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'secco')
# ('r', 'e') O ('crane', 'secco')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'sechs')
# ('r', 'e') O ('crane', 'sechs')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'sects')
# ('r', 'e') O ('crane', 'sects')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'seder')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'sedes')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'sedge')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'sedgy')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'sedum')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'seeds')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'seeks')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'seeld')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'seels')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'seely')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'seems')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'seeps')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'seepy')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'seers')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'sefer')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'segar')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'segni')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'segno')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'segol')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'segos')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'sehri')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'seifs')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'seils')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'seine')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'seirs')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'seise')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'seism')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'seity')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'seiza')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'sekos')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'sekts')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'selah')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'seles')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'selfs')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'sella')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'selle')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'sells')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'selva')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'semee')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'semes')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'semie')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'semis')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'senas')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'sends')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'senes')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'sengi')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'senna')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'senor')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'sensa')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'sensi')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'sente')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'senti')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'sents')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'senvy')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'senza')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'sepad')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'sepal')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'sepic')
# ('r', 'e') O ('crane', 'sepic')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'sepoy')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'septa')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'septs')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'serac')
# ('r', 'e') O ('crane', 'serac')
# ('a', 'r') - ('crane', 'serac')
#    l1 in candidate and t != 'O':
# ('c', 's') O ('crane', 'serai')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'seral')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'sered')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'serer')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'seres')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'serfs')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'serge')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'seric')
# ('r', 'e') O ('crane', 'seric')
# ('a', 'r') - ('crane', 'seric')
# ('n', 'i') - ('crane', 'seric')
# ('e', 'c') O ('crane', 'seric')
# ('c', 's') O ('crane', 'serin')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'serks')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'seron')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'serow')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'serra')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'serre')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'serrs')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'serry')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'servo')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'sesey')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'sessa')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'setae')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'setal')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'seton')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'setts')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'sewan')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'sewar')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'sewed')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'sewel')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'sewen')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'sewin')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'sexed')
#    l1 not in candidate and t == 'O':
# ('c', 's') O ('crane', 'sexer')
#    l1 not in candidate and t == 'O':
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [246], in <module>
#       1 answers_left = narrow_down('crane', 'OO--O', answers)
# ----> 2 allowed_left = narrow_down('crane', 'OO--O', allowed)
#
# Input In [245], in narrow_down(guess, template, words_left)
#      26 def narrow_down(guess, template, words_left=answers.copy()):
#      27     """ Accepts a wordle guess, and the number of words left;
#      28         defaults to all possible words left (for 1st turn)
#      29         and returns list of remaining possible words """
# ---> 30     return [cand for cand in words_left if check_cand(guess, template, cand)]
#
# Input In [245], in <listcomp>(.0)
#      26 def narrow_down(guess, template, words_left=answers.copy()):
#      27     """ Accepts a wordle guess, and the number of words left;
#      28         defaults to all possible words left (for 1st turn)
#      29         and returns list of remaining possible words """
# ---> 30     return [cand for cand in words_left if check_cand(guess, template, cand)]
#
# Input In [245], in check_cand(guess, template, candidate)
#      11     return False
#      12 if l1 not in candidate and t == 'O':
# ---> 13     print("   l1 not in candidate and t == 'O':")
#      14     return False
#      15 if l1 in candidate and t != 'O':
#
# File ~/.pyenv/versions/3.10.0/envs/wordle/lib/python3.10/site-packages/ipykernel/iostream.py:531, in OutStream.write(self, string)
#     529 is_child = (not self._is_master_process())
#     530 # only touch the buffer in the IO thread to avoid races
# --> 531 self.pub_thread.schedule(lambda: self._buffer.write(string))
#     532 if is_child:
#     533     # mp.Pool cannot be trusted to flush promptly (or ever),
#     534     # and this helps.
#     535     if self._subprocess_flush_pending:
#
# File ~/.pyenv/versions/3.10.0/envs/wordle/lib/python3.10/site-packages/ipykernel/iostream.py:216, in IOPubThread.schedule(self, f)
#     214     self._events.append(f)
#     215     # wake event thread (message content is ignored)
# --> 216     self._event_pipe.send(b'')
#     217 else:
#     218     f()
#
# File ~/.pyenv/versions/3.10.0/envs/wordle/lib/python3.10/site-packages/zmq/sugar/socket.py:547, in Socket.send(self, data, flags, copy, track, routing_id, group)
#     540         data = zmq.Frame(
#     541             data,
#     542             track=track,
#     543             copy=copy or None,
#     544             copy_threshold=self.copy_threshold,
#     545         )
#     546     data.group = group
# --> 547 return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#
# File zmq/backend/cython/socket.pyx:718, in zmq.backend.cython.socket.Socket.send()
#
# File zmq/backend/cython/socket.pyx:765, in zmq.backend.cython.socket.Socket.send()
#
# File zmq/backend/cython/socket.pyx:242, in zmq.backend.cython.socket._send_copy()
#
# File ~/.pyenv/versions/3.10.0/envs/wordle/lib/python3.10/site-packages/zmq/backend/cython/checkrc.pxd:13, in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
g_dict = {}
all_left = allowed_left + answers_left
all_left.sort()
for guess in all_left: # a possible word that is allowed
    gbin[guess] = {}
    for answer in answers_left:  # a potential answer
        template = make_template(guess, answer)
        gbin[guess][template] = narrow_down(guess, template, answers_left)

# %%
np.log2(3)
# Out:
# 1.584962500721156

# %%
entropy_bin = []

for guess in gbin:
    print(guess)
    entropy = 0
    for template in gbin[guess]:
        print(f".... {template}:  {', '.join(gbin[guess][template])}")
        entropy += np.log2(len(gbin[guess][template]))
    print(f"Entropy score (higher is worse): {entropy}")
    entropy_bin += [(guess, entropy)]

entropy_bin.sort(key=lambda x: x[1], reverse=True)
best = [x for x in entropy_bin if x[1] == entropy_bin[-1][1]]

print("Best guess(es): ")
for (guess, entropy_val) in best:
    print(f"* {guess} [{entropy_val}]")
# Out:
# decor
# .... XXXXX:  decor
# .... XXX-O:  decry
# .... -XO-O:  mercy, perch, relic, retch
# .... -XX-X:  recur
# .... -XX-O:  recut
# .... -OO-O:  screw
# .... -OX-X:  ulcer
# Entropy score (higher is worse): 2.0
# decry
# .... XXXO-:  decor
# .... XXXXX:  decry
# .... -XOOX:  mercy
# .... -XOO-:  perch, relic, retch
# .... -XXO-:  recur, recut
# .... -OOO-:  screw
# .... -OXO-:  ulcer
# Entropy score (higher is worse): 2.584962500721156
# dicer
# .... X-XOX:  decor
# .... X-XOO:  decry
# .... --OOO:  mercy, perch, retch
# .... --XOX:  recur
# .... --XOO:  recut
# .... -OOOO:  relic
# .... --OXO:  screw
# .... --XXX:  ulcer
# Entropy score (higher is worse): 1.584962500721156
# ecrus
# .... OOO--:  decor, decry, relic, retch
# .... OOX--:  mercy, perch
# .... OOOX-:  recur, recut
# .... OXX-O:  screw
# .... OOOO-:  ulcer
# Entropy score (higher is worse): 4.0
# icers
# .... -OOO-:  decor, mercy, perch, recur, recut, retch, ulcer
# .... -OOX-:  decry
# .... OOOO-:  relic
# .... -XOOO:  screw
# Entropy score (higher is worse): 2.807354922057604
# icier
# .... -O-OX:  decor, recur
# .... -O-OO:  decry, mercy, perch, recut, retch
# .... OOOOO:  relic
# .... -X-XO:  screw
# .... -O-XX:  ulcer
# Entropy score (higher is worse): 3.321928094887362
# icker
# .... -O-OX:  decor, recur
# .... -O-OO:  decry, mercy, perch, recut, retch
# .... OO-OO:  relic
# .... -X-XO:  screw
# .... -O-XX:  ulcer
# Entropy score (higher is worse): 3.321928094887362
# merch
# .... -XOO-:  decor, decry, recur, recut, relic
# .... XXXX-:  mercy
# .... -XXXX:  perch
# .... -XOXX:  retch
# .... -OXO-:  screw
# .... -OOO-:  ulcer
# Entropy score (higher is worse): 2.321928094887362
# mercs
# .... -XOO-:  decor, decry, recur, recut, relic
# .... XXXX-:  mercy
# .... -XXX-:  perch
# .... -XOX-:  retch
# .... -OXOO:  screw
# .... -OOO-:  ulcer
# Entropy score (higher is worse): 2.321928094887362
# mercy
# .... -XOO-:  decor, recur, recut, relic
# .... -XOOX:  decry
# .... XXXXX:  mercy
# .... -XXX-:  perch
# .... -XOX-:  retch
# .... -OXO-:  screw
# .... -OOO-:  ulcer
# Entropy score (higher is worse): 2.0
# ocher
# .... OO-OX:  decor
# .... -O-OO:  decry, mercy, recut, relic
# .... -OOOO:  perch, retch
# .... -O-OX:  recur
# .... -X-XO:  screw
# .... -O-XX:  ulcer
# Entropy score (higher is worse): 3.0
# ocker
# .... OO-OX:  decor
# .... -O-OO:  decry, mercy, perch, recut, relic, retch
# .... -O-OX:  recur
# .... -X-XO:  screw
# .... -O-XX:  ulcer
# Entropy score (higher is worse): 2.584962500721156
# perch
# .... -XOO-:  decor, decry, recur, recut, relic
# .... -XXX-:  mercy
# .... XXXXX:  perch
# .... -XOXX:  retch
# .... -OXO-:  screw
# .... -OOO-:  ulcer
# Entropy score (higher is worse): 2.321928094887362
# percs
# .... -XOO-:  decor, decry, recur, recut, relic
# .... -XXX-:  mercy
# .... XXXX-:  perch
# .... -XOX-:  retch
# .... -OXOO:  screw
# .... -OOO-:  ulcer
# Entropy score (higher is worse): 2.321928094887362
# pucer
# .... --XOX:  decor
# .... --XOO:  decry
# .... --OOO:  mercy, relic, retch
# .... X-OOO:  perch
# .... -OXOX:  recur
# .... -OXOO:  recut
# .... --OXO:  screw
# .... -OXXX:  ulcer
# Entropy score (higher is worse): 1.584962500721156
# rebec
# .... OX-OO:  decor, decry, mercy, perch
# .... XX-OO:  recur, recut, retch
# .... XX-OX:  relic
# .... OO-XO:  screw, ulcer
# Entropy score (higher is worse): 4.584962500721156
# recco
# .... OXXOO:  decor
# .... OXXO-:  decry
# .... OXOX-:  mercy, perch
# .... XXXO-:  recur, recut
# .... XXOO-:  relic
# .... XXOX-:  retch
# .... OOOO-:  screw
# .... OOXO-:  ulcer
# Entropy score (higher is worse): 2.0
# reccy
# .... OXXO-:  decor
# .... OXXOX:  decry
# .... OXOXX:  mercy
# .... OXOX-:  perch
# .... XXXO-:  recur, recut
# .... XXOO-:  relic
# .... XXOX-:  retch
# .... OOOO-:  screw
# .... OOXO-:  ulcer
# Entropy score (higher is worse): 1.0
# recit
# .... OXX--:  decor, decry
# .... OXO--:  mercy, perch
# .... XXX--:  recur
# .... XXX-X:  recut
# .... XXOX-:  relic
# .... XXO-O:  retch
# .... OOO--:  screw
# .... OOX--:  ulcer
# Entropy score (higher is worse): 2.0
# recks
# .... OXX--:  decor, decry
# .... OXO--:  mercy, perch
# .... XXX--:  recur, recut
# .... XXO--:  relic, retch
# .... OOO-O:  screw
# .... OOX--:  ulcer
# Entropy score (higher is worse): 4.0
# recti
# .... OXX--:  decor, decry
# .... OXO--:  mercy, perch
# .... XXX--:  recur
# .... XXXO-:  recut
# .... XXO-O:  relic
# .... XXOO-:  retch
# .... OOO--:  screw
# .... OOX--:  ulcer
# Entropy score (higher is worse): 2.0
# recto
# .... OXX-O:  decor
# .... OXX--:  decry
# .... OXO--:  mercy, perch
# .... XXX--:  recur
# .... XXXO-:  recut
# .... XXO--:  relic
# .... XXOO-:  retch
# .... OOO--:  screw
# .... OOX--:  ulcer
# Entropy score (higher is worse): 1.0
# recur
# .... OXX-X:  decor
# .... OXX-O:  decry
# .... OXO-O:  mercy, perch
# .... XXXXX:  recur
# .... XXXXO:  recut
# .... XXO-O:  relic, retch
# .... OOO-O:  screw
# .... OOXOX:  ulcer
# Entropy score (higher is worse): 2.0
# recut
# .... OXX--:  decor, decry
# .... OXO--:  mercy, perch
# .... XXXX-:  recur
# .... XXXXX:  recut
# .... XXO--:  relic
# .... XXO-O:  retch
# .... OOO--:  screw
# .... OOXO-:  ulcer
# Entropy score (higher is worse): 2.0
# reech
# .... OXOO-:  decor, decry
# .... OXOX-:  mercy
# .... OXOXX:  perch
# .... XXOO-:  recur, recut, relic
# .... XXOXX:  retch
# .... OOOO-:  screw, ulcer
# Entropy score (higher is worse): 3.584962500721156
# relic
# .... OX--O:  decor, decry, mercy, perch
# .... XX--O:  recur, recut, retch
# .... XXXXX:  relic
# .... OO--O:  screw
# .... OOO-O:  ulcer
# Entropy score (higher is worse): 3.584962500721156
# retch
# .... OX-O-:  decor, decry
# .... OX-X-:  mercy
# .... OX-XX:  perch
# .... XX-O-:  recur, relic
# .... XXOO-:  recut
# .... XXXXX:  retch
# .... OO-O-:  screw, ulcer
# Entropy score (higher is worse): 3.0
# riced
# .... O-XOO:  decor, decry
# .... O-OO-:  mercy, perch
# .... X-XO-:  recur, recut
# .... XOOO-:  relic
# .... X-OO-:  retch
# .... O-OX-:  screw
# .... O-XX-:  ulcer
# Entropy score (higher is worse): 3.0
# ricer
# .... O-XOX:  decor
# .... O-XOO:  decry
# .... O-OOO:  mercy, perch
# .... X-XOX:  recur
# .... X-XOO:  recut
# .... XOOOO:  relic
# .... X-OOO:  retch
# .... O-OXO:  screw
# .... O-XXX:  ulcer
# Entropy score (higher is worse): 1.0
# rices
# .... O-XO-:  decor, decry
# .... O-OO-:  mercy, perch
# .... X-XO-:  recur, recut
# .... XOOO-:  relic
# .... X-OO-:  retch
# .... O-OXO:  screw
# .... O-XX-:  ulcer
# Entropy score (higher is worse): 3.0
# ricey
# .... O-XO-:  decor
# .... O-XOX:  decry
# .... O-OOX:  mercy
# .... O-OO-:  perch
# .... X-XO-:  recur, recut
# .... XOOO-:  relic
# .... X-OO-:  retch
# .... O-OX-:  screw
# .... O-XX-:  ulcer
# Entropy score (higher is worse): 1.0
# screw
# .... -OOO-:  decor, decry, recur, recut, relic, retch
# .... -OXO-:  mercy, perch
# .... XXXXX:  screw
# .... -OOX-:  ulcer
# Entropy score (higher is worse): 3.584962500721156
# seric
# .... -XO-O:  decor, decry, recur, recut, retch
# .... -XX-O:  mercy, perch
# .... -XOXX:  relic
# .... XOX-O:  screw
# .... -OO-O:  ulcer
# Entropy score (higher is worse): 3.321928094887362
# ulcer
# .... --XOX:  decor
# .... --XOO:  decry
# .... --OOO:  mercy, perch, retch
# .... O-XOX:  recur
# .... O-XOO:  recut
# .... -OOOO:  relic
# .... --OXO:  screw
# .... XXXXX:  ulcer
# Entropy score (higher is worse): 1.584962500721156
# xeric
# .... -XO-O:  decor, decry, recur, recut, retch
# .... -XX-O:  mercy, perch
# .... -XOXX:  relic
# .... -OX-O:  screw
# .... -OO-O:  ulcer
# Entropy score (higher is worse): 3.321928094887362
# Best guess(es):
# * reccy [1.0]
# * recto [1.0]
# * ricer [1.0]
# * ricey [1.0]

# %%
def score_word(word, guess, entropy=True, left=answers):
    score = ""
    words_left = set(left.copy())
    for i, (l1, l2) in enumerate(zip(word, guess)):
        if l1 == l2:
            score += "X"
            words_left = [x for x in words_left if x[i] == l1]
        elif l2 in word:
            score += "O"
            words_left = [x for x in words_left if l1 in x]
        else:
            score += "-"
            words_left = [x for x in words_left if l1 not in x]
    return score, words_left

# %%
guess_bin = {}
overall = {}
for guess in narrow:
    guess_bin[guess] = {}
    overall[guess] = 0.0
    for pos in narrow:
        pattern, wo_left = score_word(pos, guess, left=narrow)
        if len(wo_left) == 0:
            continue
        guess_bin[guess][pos] = (pattern, len(wo_left))
        overall[guess] += len(wo_left)

# %%
for guess in guess_bin:
    print(guess)
    tot = 0
    for left in guess_bin[guess]:
        print(f"... {left}: {guess_bin[guess][left]}")
        tot += guess_bin[guess][left][1]
    print(f"... Other: {len(guess_bin) - tot}")
# Out:
# decor
# ... decor: ('XXXXX', 1)
# ... Other: 9
# decry
# ... decry: ('XXXXX', 1)
# ... mercy: ('-XOOX', 1)
# ... perch: ('-XOO-', 6)
# ... screw: ('-OOO-', 9)
# ... Other: -7
# mercy
# ... decry: ('-XOOX', 1)
# ... mercy: ('XXXXX', 1)
# ... perch: ('-XXX-', 1)
# ... screw: ('-OXO-', 2)
# ... Other: 5
# perch
# ... decry: ('-XOO-', 5)
# ... mercy: ('-XXX-', 1)
# ... perch: ('XXXXX', 1)
# ... screw: ('-OXO-', 2)
# ... Other: 1
# recur
# ... recur: ('XXXXX', 1)
# ... recut: ('XXXXO', 1)
# ... ulcer: ('OOXOX', 1)
# ... Other: 7
# recut
# ... recut: ('XXXXX', 1)
# ... Other: 9
# relic
# ... relic: ('XXXXX', 1)
# ... Other: 9
# retch
# ... recut: ('XXOO-', 1)
# ... retch: ('XXXXX', 1)
# ... Other: 8
# screw
# ... decry: ('-OOO-', 7)
# ... mercy: ('-OXO-', 2)
# ... perch: ('-OXO-', 2)
# ... screw: ('XXXXX', 1)
# ... Other: -2
# ulcer
# ... ulcer: ('XXXXX', 1)
# ... Other: 9

# %%
for word in narrow:
    if l1 == "c" and (l1 == l2 or l1 not in pos):
        good = False
        break
    if l1 == "r" and (l1 == l2 or l1 not in pos):
        print("2")
        good = False
        break
    if l1 == "e" and (l1 == l2 or l1 not in pos):
        print("3")
        good = False
        break
    if good:
        crane_cre_allowed += [pos]

# %%
narrow
# Out:
# ['decor',
#  'decry',
#  'mercy',
#  'perch',
#  'recur',
#  'recut',
#  'relic',
#  'retch',
#  'screw',
#  'ulcer']

# %%
turn1 = narrow_down('crane', 'OO--O')

# %%
turn2 = narrow_down('perch', '-OOO-', turn1)

# %%
turn2
# Out:
# ['ulcer']
